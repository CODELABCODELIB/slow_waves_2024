# %%
import numpy as np
import pandas as pd
import statsmodels.tsa as tsa
from statsmodels.tsa.vector_ar.var_model import VAR, FEVD
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, adfuller, ccf, ccovf, kpss
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
#import mvts_utils as utils
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load in the data

# %%
import h5py
file_name = '../../../data/jid_playground/jid_eeg.h5'

# %%
df1 = pd.DataFrame(np.array(h5py.File(file_name)['bin1530']))
df1 = df1.dropna()

# %%
df1.head(10)
# Out:
#          0         1         2         3          4         5         6   \
# 0 -5.010096 -7.471970 -5.222030 -0.070401   0.723151 -2.652430 -6.562227
# 1 -4.491299 -6.828745 -4.413321  1.044307   1.789987 -1.629328 -6.489788
# 2 -3.945387 -6.167099 -3.631674  2.148291   2.862839 -0.559727 -6.425260
# 3 -3.355640 -5.470657 -2.871424  3.237437   3.942619  0.561986 -6.343477
# 4 -2.704514 -4.721220 -2.124459  4.308027   5.028917  1.739042 -6.215683
# 5 -1.979359 -3.903050 -1.381531  5.358114   6.121176  2.970496 -6.015847
# 6 -1.176286 -3.005726 -0.634780  6.384256   7.215928  4.248088 -5.724364
# 7 -0.294545 -2.020450  0.124808  7.384039   8.308808  5.560336 -5.324624
# 8  0.660938 -0.943785  0.904615  8.354674   9.393373  6.890951 -4.807120
# 9  1.678143  0.220552  1.707091  9.288980  10.457879  8.217284 -4.168167
#
#           7          8          9         10         11         12         13  \
# 0 -11.239132 -13.338441 -10.478822 -8.695134   3.495069   7.402113   5.610150
# 1 -11.633616 -13.809785 -10.251541 -8.019357   4.351437   8.323714   6.676959
# 2 -12.033147 -14.298256 -10.038291 -7.347164   5.181018   9.180624   7.666557
# 3 -12.396767 -14.769664  -9.825912 -6.675950   5.980307   9.970985   8.580307
# 4 -12.678290 -15.184535  -9.597308 -6.001185   6.745623  10.693322   9.420053
# 5 -12.833339 -15.504816  -9.334839 -5.315282   7.477230  11.350522  10.191045
# 6 -12.824555 -15.694895  -9.019820 -4.609226   8.176850  11.947125  10.900816
# 7 -12.619161 -15.721168  -8.632700 -3.872552   8.847152  12.489448  11.558286
# 8 -12.194385 -15.558471  -8.158363 -3.096441   9.490488  12.983164  12.172211
# 9 -11.535251 -15.186763  -7.584366 -2.275193  10.105872  13.429571  12.747585
#
#           14         15         16        17        18         19         20  \
# 0   7.682362   2.485868  -2.847615 -9.870010 -8.441239 -12.492434 -16.769333
# 1   8.787175   3.643477  -1.524850 -9.004733 -8.646618 -12.731614 -17.495449
# 2   9.830449   4.817129  -0.130689 -8.081794 -8.863778 -12.939323 -18.225274
# 3  10.814612   6.006771   1.331187 -7.093182 -9.069839 -13.093216 -18.926548
# 4  11.741548   7.209866   2.854163 -6.031040 -9.237110 -13.167007 -19.558290
# 5  12.614622   8.420755   4.426396 -4.892204 -9.339246 -13.135407 -20.078458
# 6  13.437915   9.631022   6.029806 -3.679679 -9.354583 -12.978831 -20.447438
# 7  14.215120  10.830460   7.644096 -2.399523 -9.263743 -12.680997 -20.628277
# 8  14.948042  12.003729   9.244208 -1.063413 -9.053688 -12.231839 -20.593770
# 9  15.635892  13.131829  10.799755  0.312152 -8.715250 -11.625173 -20.319088
#
#           21         22        23         24         25         26         27  \
# 0 -14.252149 -11.520980 -2.269031   6.028826  11.187862  10.847127   8.542318
# 1 -14.781206 -11.599127 -1.990260   6.665788  12.272936  11.491616   9.116556
# 2 -15.277497 -11.662260 -1.688631   7.299426  13.270698  12.043616   9.599265
# 3 -15.724147 -11.701066 -1.361265   7.928347  14.167076  12.508096  10.004250
# 4 -16.100842 -11.704092 -1.007260   8.548128  14.946810  12.888419  10.344194
# 5 -16.390047 -11.660011 -0.624433   9.157818  15.602564  13.193525  10.635074
# 6 -16.573302 -11.555635 -0.209585   9.756241  16.131457  13.436385  10.894932
# 7 -16.633800 -11.377734  0.239730  10.341336  16.534423  13.630192  11.139545
# 8 -16.561985 -11.118203  0.722555  10.910437  16.816401  13.789203  11.384882
# 9 -16.347108 -10.768761  1.235476  11.456070  16.978992  13.922821  11.642964
#
#           28         29         30        31        32         33         34  \
# 0   9.179890   7.927500   3.597815 -5.730086 -7.406996 -13.348417 -17.855223
# 1   9.938976   8.876236   4.718466 -4.284939 -6.612558 -13.373885 -18.224488
# 2  10.595039   9.776884   5.818368 -2.813693 -5.796369 -13.360626 -18.520466
# 3  11.158798  10.629149   6.889274 -1.331616 -4.957900 -13.302070 -18.736800
# 4  11.641419  11.432998   7.923862  0.148263 -4.093903 -13.187480 -18.859674
# 5  12.055954  12.187787   8.913711  1.610638 -3.203000 -13.007010 -18.875152
# 6  12.416471  12.891303   9.848846  3.038242 -2.286940 -12.754042 -18.775898
# 7  12.736574  13.540984  10.719562  4.415891 -1.348461 -12.424223 -18.555955
# 8  13.028674  14.131701  11.513760  5.726810 -0.394312 -12.017103 -18.213660
# 9  13.302048  14.656090  12.218868  6.954293  0.568037 -11.531110 -17.746112
#
#           35         36         37        38        39         40         41  \
# 0 -16.321465 -15.114702 -16.208868 -4.496713  1.828125   7.993218   9.817261
# 1 -17.282229 -16.061420 -16.661279 -4.609322  1.967846   8.814011  10.622403
# 2 -18.197906 -16.954299 -17.026317 -4.653344  2.142533   9.624267  11.350088
# 3 -19.051096 -17.775642 -17.298152 -4.623788  2.348230  10.407728  11.989014
# 4 -19.819430 -18.503670 -17.469801 -4.516792  2.578706  11.143586  12.523570
# 5 -20.479498 -19.117014 -17.535604 -4.329565  2.831385  11.820608  12.948464
# 6 -21.011272 -19.598226 -17.491888 -4.061638  3.098361  12.425717  13.263391
# 7 -21.397612 -19.931906 -17.335172 -3.713852  3.370612  12.949955  13.470120
# 8 -21.627212 -20.109986 -17.068665 -3.291013  3.644961  13.389959  13.579245
# 9 -21.687568 -20.125108 -16.695055 -2.799717  3.912252  13.731720  13.595225
#
#          42         43         44         45         46         47         48  \
# 0  6.451142   8.817136   9.405194   9.128022   4.702094 -10.780096 -13.300745
# 1  6.825346   9.168784   9.848298   9.590685   5.786643  -8.986489 -12.086404
# 2  7.151344   9.443386  10.199266   9.969626   6.788320  -7.193162 -10.840160
# 3  7.436687   9.653725  10.469426  10.269864   7.696804  -5.430766  -9.579368
# 4  7.680506   9.810357  10.668868  10.498580   8.505565  -3.725208  -8.317902
# 5  7.888340   9.925292  10.810685  10.662493   9.209854  -2.099924  -7.068896
# 6  8.071754  10.012224  10.909384  10.768091   9.805711  -0.575993  -5.846745
# 7  8.231253  10.081997  10.977483  10.822099  10.291928   0.829944  -4.664616
# 8  8.377015  10.147690  11.026686  10.828412  10.667786   2.104031  -3.535009
# 9  8.519656  10.219382  11.067253  10.790784  10.933847   3.237937  -2.467156
#
#           49         50        51        52        53        54        55  \
# 0 -13.931581 -14.275133 -6.330503  1.989184  3.820010  7.028954  5.995666
# 1 -15.300385 -15.176196 -6.378485  2.106721  4.108256  7.439434  6.300874
# 2 -16.637441 -16.022073 -6.367626  2.256020  4.412998  7.817303  6.559119
# 3 -17.922386 -16.800238 -6.298041  2.433225  4.719835  8.158213  6.774764
# 4 -19.130455 -17.495707 -6.170867  2.632321  5.008596  8.445895  6.938065
# 5 -20.235920 -18.093349 -5.988981  2.850962  5.275367  8.674905  7.051445
# 6 -21.216379 -18.580111 -5.757928  3.081752  5.504440  8.842252  7.125789
# 7 -22.052909 -18.945962 -5.484144  3.316340  5.685813  8.942645  7.150520
# 8 -22.733513 -19.187420 -5.174113  3.551821  5.822230  8.987192  7.139288
# 9 -23.244194 -19.298418 -4.835291  3.779503  5.897571  8.974453  7.111066
#
#          56        57        58        59        60        61         62  \
# 0  5.653932  6.330503  7.878602 -1.102596  5.420872  1.802149 -11.906279
# 1  5.761249  6.378485  8.037969 -0.507142  5.544762  1.947830 -13.441756
# 2  5.836583  6.367626  8.107315 -0.001124  5.637582  2.129559 -15.001736
# 3  5.885463  6.298041  8.090084  0.406886  5.703703  2.342007 -16.565142
# 4  5.907337  6.170867  7.993413  0.715090  5.742066  2.577734 -18.103928
# 5  5.906944  5.988981  7.823563  0.926273  5.756660  2.832658 -19.584410
# 6  5.892355  5.757928  7.588412  1.046173  5.754869  3.097565 -20.973213
# 7  5.867401  5.484144  7.297477  1.082440  5.740458  3.362567 -22.242505
# 8  5.841561  5.174113  6.957234  1.044954  5.722693  3.623326 -23.367226
# 9  5.822166  4.835291  6.576624  0.949030  5.708735  3.870147 -24.317905
#
#           63
# 0 -20.907515
# 1 -23.699014
# 2 -26.447206
# 3 -29.109174
# 4 -31.638464
# 5 -33.984796
# 6 -36.101838
# 7 -37.954384
# 8 -39.515026
# 9 -40.754148

# %%
df1.T.iloc[0].head(10)
# Out:
# 0   -5.010096
# 1   -4.491299
# 2   -3.945387
# 3   -3.355640
# 4   -2.704514
# 5   -1.979359
# 6   -1.176286
# 7   -0.294545
# 8    0.660938
# 9    1.678143
# Name: 0, dtype: float64

# %%
data_df = df1.iloc[:,0:62]

# %% [markdown]
# # Explore data

# %%
im = plt.matshow(df1.T,aspect ='auto', vmin=-20, vmax=20)
plt.colorbar()
plt.show()

# %%
fig,ax = plt.subplots(16,4, figsize=(15,15), sharex=True)
df1.plot(color='k',ax=ax, subplots=True)
plt.show()

# %% [markdown]
# # Check if the variables are correlated at different time lags

# %% [markdown]
# ## Correlation/covariance between electrodes

# %%
corr = np.corrcoef(data_df.T)
fig, (ax1, ax2) = plt.subplots(1,2)
im = ax1.matshow(corr,aspect ='equal', vmin=-1, vmax=1)
ax1.set_xticks(np.arange(0,64,5))
ax1.set_yticks(np.arange(0,64,5))
ax1.grid(which='both')
#fig.colorbar(im)
ax1.set_title(label='Correlation')
fig.show()

covv = np.cov(data_df.T)
im = ax2.matshow(covv,aspect ='equal', vmin=-50, vmax=50)
ax2.set_xticks(np.arange(0,64,5))
ax2.set_yticks(np.arange(0,64,5))
ax2.grid(which='both')
#fig.colorbar(im)
ax2.set_title(label='Covariance')
fig.show()

# %%
plt.imshow(corr_mask)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Cross correlation

# %%
ccf(df1[0],df1[1], unbiased=False)
# Out:
# array([9.20883201e-01, 9.10660597e-01, 8.89619415e-01, ...,
#        8.79382129e-04, 6.44583438e-04, 3.50950558e-04])

# %%
ccf_y1_y2 = ccf(df1[5],df1[15], unbiased=False)
ccf_y2_y1 = ccf(df1[0],df1[63], unbiased=False)
fig, ax = plt.subplots(2, figsize=(15, 4), sharex=True, sharey=True)
d=10
ax[0].stem(np.arange(len(df1.T.iloc[0]))[::d], ccf_y1_y2[::d], linefmt='C1-', markerfmt='C1o')
ax[1].stem(np.arange(len(df1.T.iloc[0]))[::d], ccf_y2_y1[::d], linefmt='C1-', markerfmt='C1o')
ax[-1].set_ylim(-1, 1)
ax[-1].set_xlabel('lag $h$', fontsize=14)
ax[0].set_ylabel(r'$\rho_{CO,NO2} (h)$', fontsize=14)
ax[1].set_ylabel(r'$\rho_{NO2,CO} (h)$', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cluster electrodes

# %%
from sklearn import metrics
from sklearn.cluster import HDBSCAN

# %%
db = HDBSCAN(min_cluster_size=2,store_centers='both').fit(data_df.T)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Estimated number of clusters: 19
# Estimated number of noise points: 12

# %%
_, indexes = np.unique(labels[db.probabilities_ == 1], return_index=True)
_, indexes = np.unique(labels, return_index=True)

# %%
labels
# Out:
# array([17,  6,  6, 18, 18, 17, 11,  2, -1,  5,  5,  3, 14, 14, 14, 14, -1,
#        11, 11,  2, -1,  8,  8, -1,  3,  3, -1, 14, -1, 15, 15, 16, 16, -1,
#        -1,  1,  9,  8, -1, 13,  3,  3,  7,  7, 15, 15,  4,  0,  0,  1,  9,
#        -1, 13, 13, 12, 12, 10, -1,  4, -1, 10, 13])

# %%
np.isin(np.arange(len(labels)), indexes) | (labels == -1)
# Out:
# array([ True,  True, False,  True, False, False,  True,  True,  True,
#         True, False,  True,  True, False, False, False,  True, False,
#        False, False,  True,  True, False,  True, False, False,  True,
#        False,  True,  True, False,  True, False,  True,  True,  True,
#         True, False,  True,  True, False, False,  True, False, False,
#        False,  True,  True, False, False, False,  True, False, False,
#         True, False,  True,  True, False,  True, False, False])

# %%
sel_data = data_df.iloc[:,np.isin(np.arange(len(labels)), indexes)]

# %%
corr = np.corrcoef(sel_data.T)
im = plt.matshow(corr,aspect ='equal', vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # Test for stationarity

# %% [markdown]
# ### KPSS test

# %%
test_stat, p_val = [], []
cv_1pct, cv_2p5pct, cv_5pct, cv_10pct = [], [], [], []
for c in sel_data.columns: 
    kpss_res = kpss(sel_data[c].dropna(), regression='ct')
    test_stat.append(kpss_res[0])
    p_val.append(kpss_res[1])
    cv_1pct.append(kpss_res[3]['1%'])
    cv_2p5pct.append(kpss_res[3]['1%'])
    cv_5pct.append(kpss_res[3]['5%'])
    cv_10pct.append(kpss_res[3]['10%'])
kpss_res_df = pd.DataFrame({'Test statistic': test_stat, 
                           'p-value': p_val, 
                           'Critical value - 1%': cv_1pct,
                           'Critical value - 2.5%': cv_2p5pct,
                           'Critical value - 5%': cv_5pct,
                           'Critical value - 10%': cv_10pct}, 
                         index=sel_data.columns).T
kpss_res_df.round(4)
# Out:
#                            0       1       3       6       7       8       9   \
# Test statistic         0.0474  0.0421  0.0674  0.0677  0.0402  0.0827  0.0298
# p-value                0.1000  0.1000  0.1000  0.1000  0.1000  0.1000  0.1000
# Critical value - 1%    0.2160  0.2160  0.2160  0.2160  0.2160  0.2160  0.2160
# Critical value - 2.5%  0.2160  0.2160  0.2160  0.2160  0.2160  0.2160  0.2160
# Critical value - 5%    0.1460  0.1460  0.1460  0.1460  0.1460  0.1460  0.1460
# Critical value - 10%   0.1190  0.1190  0.1190  0.1190  0.1190  0.1190  0.1190
#
#                            11      12     21      29      31      35      36  \
# Test statistic         0.0664  0.0742  0.037  0.0938  0.0797  0.0651  0.0576
# p-value                0.1000  0.1000  0.100  0.1000  0.1000  0.1000  0.1000
# Critical value - 1%    0.2160  0.2160  0.216  0.2160  0.2160  0.2160  0.2160
# Critical value - 2.5%  0.2160  0.2160  0.216  0.2160  0.2160  0.2160  0.2160
# Critical value - 5%    0.1460  0.1460  0.146  0.1460  0.1460  0.1460  0.1460
# Critical value - 10%   0.1190  0.1190  0.119  0.1190  0.1190  0.1190  0.1190
#
#                            39      42      46      47     54      56
# Test statistic         0.0518  0.0686  0.0818  0.0654  0.064  0.0665
# p-value                0.1000  0.1000  0.1000  0.1000  0.100  0.1000
# Critical value - 1%    0.2160  0.2160  0.2160  0.2160  0.216  0.2160
# Critical value - 2.5%  0.2160  0.2160  0.2160  0.2160  0.216  0.2160
# Critical value - 5%    0.1460  0.1460  0.1460  0.1460  0.146  0.1460
# Critical value - 10%   0.1190  0.1190  0.1190  0.1190  0.119  0.1190

# %% [markdown]
# ### Dickey fuller test

# %%
test_stat, p_val = [], []
cv_1pct, cv_5pct, cv_10pct = [], [], []
for c in sel_data.columns: 
    adf_res = adfuller(sel_data[c].dropna())
    test_stat.append(adf_res[0])
    p_val.append(adf_res[1])
    cv_1pct.append(adf_res[4]['1%'])
    cv_5pct.append(adf_res[4]['5%'])
    cv_10pct.append(adf_res[4]['10%'])
adf_res_df = pd.DataFrame({'Test statistic': test_stat, 
                           'p-value': p_val, 
                           'Critical value - 1%': cv_1pct,
                           'Critical value - 5%': cv_5pct,
                           'Critical value - 10%': cv_10pct}, 
                         index=sel_data.columns).T
adf_res_df.round(4)
# Out:
#                           0       1       3       6       7       8       9   \
# Test statistic       -2.8888 -3.0319 -2.6666 -2.6621 -2.9819 -2.4216 -3.2581
# p-value               0.0467  0.0320  0.0800  0.0808  0.0366  0.1357  0.0169
# Critical value - 1%  -3.4368 -3.4368 -3.4368 -3.4368 -3.4368 -3.4368 -3.4368
# Critical value - 5%  -2.8644 -2.8644 -2.8644 -2.8644 -2.8644 -2.8644 -2.8644
# Critical value - 10% -2.5683 -2.5683 -2.5683 -2.5683 -2.5683 -2.5683 -2.5683
#
#                           11      12      21      29      31      35      36  \
# Test statistic       -2.9674 -2.4862 -3.0474 -2.8174 -2.7128 -2.2830 -2.3263
# p-value               0.0381  0.1189  0.0307  0.0558  0.0718  0.1775  0.1636
# Critical value - 1%  -3.4368 -3.4368 -3.4368 -3.4368 -3.4368 -3.4368 -3.4368
# Critical value - 5%  -2.8644 -2.8644 -2.8644 -2.8644 -2.8644 -2.8644 -2.8644
# Critical value - 10% -2.5683 -2.5683 -2.5683 -2.5683 -2.5683 -2.5683 -2.5683
#
#                           39      42      46      47      54      56
# Test statistic       -4.5119 -3.8420 -2.4459 -2.5317 -4.3777 -4.0095
# p-value               0.0002  0.0025  0.1292  0.1079  0.0003  0.0014
# Critical value - 1%  -3.4368 -3.4368 -3.4368 -3.4368 -3.4368 -3.4368
# Critical value - 5%  -2.8644 -2.8644 -2.8644 -2.8644 -2.8644 -2.8644
# Critical value - 10% -2.5683 -2.5683 -2.5683 -2.5683 -2.5683 -2.5683

# %%
stationary = adf_res_df.T['p-value'] < 0.05
# Out:
# array([ True,  True,  True, False, False,  True, False,  True, False,
#         True,  True,  True, False, False, False, False, False, False,
#        False,  True, False,  True,  True,  True,  True,  True, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True,  True,  True, False, False,  True,  True, False,
#        False])

# %%
data_df = data_df.T[stationary.values]
data_df.T.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data_df = data_df.T[stationary.values]
#       2 data_df.T.head(10)
#
# NameError: name 'stationary' is not defined

# %% [markdown]
# # Split data in train and test sets

# %%
forecast_length = 20 
train_df, test_df = sel_data.iloc[:-forecast_length], sel_data.iloc[-forecast_length::]

# %%
train_df.shape
# Out:
# (1023, 20)

# %%
differenced_data = train_df.diff().dropna()

# %%
fig,ax = plt.subplots(4,5, figsize=(15, 5), sharex=True)
train_df.plot(ax=ax, subplots=True)
plt.xlabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find the best number of lags

# %%
aic, bic, fpe, hqic = [], [], [], []
model = VAR(train_df) 
p = np.arange(1,100)
for i in p:
    result = model.fit(i)
    aic.append(result.aic)
    bic.append(result.bic)
    fpe.append(result.fpe)
    hqic.append(result.hqic)
lags_metrics_df = pd.DataFrame({'AIC': aic, 
                                'BIC': bic, 
                                'HQIC': hqic,
                                'FPE': fpe}, 
                               index=p)    
fig, ax = plt.subplots(1, 4, figsize=(15, 3), sharex=True)
lags_metrics_df.plot(subplots=True, ax=ax, marker='o')
plt.tight_layout()

# %% [markdown]
# # Train and fit the model

# %%
# %%time
model = VAR(train_df) 
var_model = model.fit(42)
# Out:
# CPU times: user 2.01 s, sys: 84 ms, total: 2.09 s
# Wall time: 319 ms

# %%
forecast_var = pd.DataFrame(var_model.forecast(train_df.values, 
                                              steps=forecast_length), 
                           columns=train_df.columns, 
                           index=test_df.index)
#forecast_var = forecast_var.rename(columns={c: c+'-VAR' for c in forecast_var.columns})
for c in train_df.columns:
    fig, ax = plt.subplots(figsize=[15, 1])
    pd.concat([train_df[c],forecast_var[c]],axis=1).plot(ax=ax)
    #plt.xlabel('')
    #plt.tight_layout()
    plt.legend(loc=2)
    plt.show()
